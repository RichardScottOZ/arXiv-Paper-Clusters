# %%
import json
import pandas as pd

# %% [markdown]
# See : https://github.com/rmovva/LLM-publication-patterns-public/tree/master
#
# Cluster file from: https://cornell.box.com/s/x6bzme0pnnl0j4o4utv5cvxtlo0edv7x

# %%
with open(r'C:\Users\rscott\Downloads\cs_stat_metadata_clusters.json') as f:
    cs = f.readlines()
    for line in cs:
        ban = json.loads(line)
        if 'geoscience' in ban['abstract'].lower():
            print(ban['title'])
# Out:
# Particle filters for high-dimensional geoscience applications: a review
# Comparing seven variants of the Ensemble Kalman Filter: How many
#   synthetic experiments are needed?
# A posteriori stochastic correction of reduced models in delayed
#   acceptance MCMC, with application to multiphase subsurface inverse problems
# Power-law size distributions in geoscience revisited
# Accounting for Skill in Trend, Variability, and Autocorrelation
#   Facilitates Better Multi-Model Projections: Application to the AMOC and
#   Temperature Time Series
# Towards a Robust Parameterization for Conditioning Facies Models Using
#   Deep Variational Autoencoders and Ensemble Smoother
# Kriging Riemannian Data via Random Domain Decompositions
# A High-Dimensional Particle Filter Algorithm
# Derivative-based global sensitivity analysis for models with
#   high-dimensional inputs and functional outputs
# HexaShrink, an exact scalable framework for hexahedral meshes with
# ...

# %%
    for line in cs:
        ban = json.loads(line)
        if 'mineral' in ban['abstract'].lower():
            print(ban['title'])
# Out:
# Efficiently Learning Nonstationary Gaussian Processes for Real World
#   Impact
# Doubly robust estimators for the average treatment effect under
#   positivity violations: introducing the $e$-score
# TStarBots: Defeating the Cheating Level Builtin AI in StarCraft II in
#   the Full Game
# Modeling longitudinal data using matrix completion
# Computer vision-based framework for extracting geological lineaments
#   from optical remote sensing data
# Persistent 1-Cycles: Definition, Computation, and Its Application
# A Regressive Convolution Neural network and Support Vector Regression
#   Model for Electricity Consumption Forecasting
# Electricity consumption forecasting method based on MPSO-BP neural
#   network model
# Distinguishing correlation from causation using genome-wide association
#   studies
# An Analysis by Synthesis Approach for Automatic Vertebral Shape
#   Identification in Clinical QCT
# A Cross-validated Ensemble Approach to Robust Hypothesis Testing of
# ...
